# %%
from dotenv import load_dotenv
_ = load_dotenv()
from crewai import Crew, Process, Agent, Task

# %%
planejador_de_viagem = Agent(
    role="Planejador de Viagem",
    goal="Planejar todos os detalhes de uma viagem incluindo roteiros e atividades",
    backstory="""
    Você é um especialista em planejamentode viagens, sempre em busca de novas aventuras
    e experiências. Seu objetivo é garantir que os detalhes da viagem
    sejam organizados de maneira eficiente e agradável.
    """,
    verbose=True
)

# %%
orcamentista = Agent(
    role="Orçamentista de Viagem",
    goal="Estimar o custo total de uma viagem, considerando transporte, hopedagem, alimentação e atividades",
    backstory="""
    Você é um analista financeiro focado em viagem. Sua missão é garantir que os custos estejam
    dentro do orçamento, criando estimativas precisas para cada parte da viagem.
    """
)

# %%
planeja_roteiro = Task(
    description="Crie um roteiro detalhado para uma viagem na Europa, incluindo as cidades, atividades e transporte",
    agent=planejador_de_viagem,
    expected_output="""
    Um roteiro com a sequência de cidades a serem visitadas, as principais
    atividades e o tipo de transporte utilizado
    """
)

# %%
estima_orcamento = Task(
    description="""
    Calcule o orçamento total da viagem, levando em consideração
    as cidades, transporte, hospedagem e atividades
    """,
    agent=orcamentista,
    expected_output="""
    Uma estimativa de orçamento detalhada, com custos aproximados para cada item da viagem 
    """
)

# %%
viagem_crew = Crew(
    agents=[planejador_de_viagem, orcamentista],
    tasks=[planeja_roteiro, estima_orcamento],
    process=Process.sequential
)

# %%
result = viagem_crew.kickoff()
# Out:
# ┌───────────────────────────── 🤖 Agent Started ──────────────────────────────┐
# │                                                                             │
# │  Agent: Planejador de Viagem                                                │
# │                                                                             │
# │  Task: Crie um roteiro detalhado para uma viagem na Europa, incluindo as    │
# │  cidades, atividades e transporte                                           │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
#
# ┌─────────────────────────── ✅ Agent Final Answer ───────────────────────────┐
# │                                                                             │
# │  Agent: Planejador de Viagem                                                │
# │                                                                             │
# │  Final Answer:                                                              │
# │  **Roteiro de Viagem pela Europa: 14 dias de aventura**                     │
# │                                                                             │
# │  **Dia 1-3: Paris, França**                                                 │
# │  - **Transporte**: Chegada ao Aeroporto Charles de Gaulle (CDG) e uso do    │
# │  metrô para locomoção na cidade.                                            │
# │  - **Atividades**:                                                          │
# │    - Dia 1: Visita à Torre Eiffel e passeio pelo Rio Sena, seguido de um    │
# │  jantar em um bistrô parisiense.                                            │
# │    - Dia 2: Exploração do Museu do Louvre e caminhada pelo Jardim das       │
# │  Tulherias. À noite, assistir ao espetáculo do Moulin Rouge.                │
# │    - Dia 3: Visitar a Basílica de Sacré-Cœur, depois explorar o bairro de   │
# │  Montmartre, incluindo a fama das ruas artísticas e cafés.                  │
# │                                                                             │
# │  **Dia 4-5: Amsterdã, Países Baixos**                                       │
# │  - **Transporte**: Trem de alta velocidade de Paris para Amsterdã           │
# │  (aproximadamente 3h).                                                      │
# │  - **Atividades**:                                                          │
# │    - Dia 4: Visitar o Museu Van Gogh e passear pelo Vondelpark. À noite,    │
# │  passeio de barco pelos canais.                                             │
# │    - Dia 5: Tour pelo bairro da Luz Vermelha e visita à Casa de Anne        │
# │  Frank.                                                                     │
# │                                                                             │
# │  **Dia 6-7: Berlim, Alemanha**                                              │
# │  - **Transporte**: Trem de Amsterdã para Berlim (aproximadamente 6h).       │
# │  - **Atividades**:                                                          │
# │    - Dia 6: Visita ao Portão de Brandemburgo, Memorial do Holocausto e      │
# │  Passeio pela Unter den Linden.                                             │
# │    - Dia 7: Exploração do Muro de Berlim e visita ao Museu da História da   │
# │  Alemanha. Aproveitar a vida noturna no bairro de Kreuzberg.                │
# │                                                                             │
# │  **Dia 8-9: Praga, República Tcheca**                                       │
# │  - **Transporte**: Trem de Berlim para Praga (aproximadamente 4h).          │
# │  - **Atividades**:                                                          │
# │    - Dia 8: Passeio pela Cidade Velha, incluindo a Praça da Cidade Velha e  │
# │  a Ponte Carlos.                                                            │
# │    - Dia 9: Visita ao Castelo de Praga e à Catedral de São Vito.            │
# │  Aproveitar a culinária local em uma cervejaria tcheca.                     │
# │                                                                             │
# │  **Dia 10-11: Viena, Áustria**                                              │
# │  - **Transporte**: Trem de Praga para Viena (aproximadamente 4h).           │
# │  - **Atividades**:                                                          │
# │    - Dia 10: Visita ao Palácio de Schönbrunn e ao Jardim de Schönbrunn.     │
# │    - Dia 11: Observable ao Museu de História da Arte e um concerto          │
# │  opcional em uma das famosas salas de concerto de Viena.                    │
# │                                                                             │
# │  **Dia 12-14: Roma, Itália**                                                │
# │  - **Transporte**: Voo direto de Viena para Roma (aproximadamente 1h        │
# │  30min).                                                                    │
# │  - **Atividades**:                                                          │
# │    - Dia 12: Visita ao Coliseu e ao Fórum Romano, seguido de um jantar      │
# │  típico italiano no Trastevere.                                             │
# │    - Dia 13: Visita ao Vaticano, incluindo a Basílica de São Pedro e a      │
# │  Capela Sistina. À noite, explore a Fontana di Trevi e desfrute de gelato.  │
# │    - Dia 14: Manhã livre para compras ou visita ao Panteão e depois         │
# │  embarque no seu voo de retorno.                                            │
# │                                                                             │
# │  **Transporte geral**: Utilize trens intermunicipais para longas            │
# │  distâncias (compre com antecedência para melhores preços) e transporte     │
# │  público nas cidades (metrôs, bondes e ônibus) para locomoção ágil e        │
# │  eficaz.                                                                    │
# │                                                                             │
# │  Esse roteiro proporciona uma imersão nas culturas europeias, equilibrando  │
# │  arte, história e gastronomia, garantido memórias inesquecíveis.            │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
# c:\Users\mains\OneDrive\Área de Trabalho\agents_course\venv\Lib\site-packages\pydantic\main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='I now ca...: None}, annotations=[]), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...ider_specific_fields={}), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(

# %%
print(result.raw)
# Out:
# **Orçamento Total da Viagem pela Europa: 14 Dias**
#
# **1. Transporte:**
# - **Chegada ao Aeroporto Charles de Gaulle (CDG)**:
#   - Transfer (táxi ou transporte privado): €60
#
# - **Transporte dentro de Paris (3 dias)**:
#   - Cartão de transporte público (metrô): €30 (cerca de €10/dia)
#
# - **Trem de alta velocidade de Paris para Amsterdã**:
#   - Bilhete: €50
#
# - **Trem de Amsterdã para Berlim**:
#   - Bilhete: €50
#
# - **Trem de Berlim para Praga**:
#   - Bilhete: €30
#
# - **Trem de Praga para Viena**:
#   - Bilhete: €20
#
# - **Voo direto de Viena para Roma**:
#   - Bilhete: €70
#
# - **Transporte dentro das cidades restantes (Amsterdã, Berlim, Praga, Viena e Roma - 11 dias)**:
#   - Cartões de transporte público: €55
#
# **Subtotal Transporte**: €60 + €30 + €50 + €50 + €30 + €20 + €70 + €55 = **€365**
#
# ---
#
# **2. Hospedagem (14 noites)**:
# - **Paris (3 noites)**:
#   - Hotel: €120/noite → €360
#
# - **Amsterdã (2 noites)**:
#   - Hotel: €100/noite → €200
#
# - **Berlim (2 noites)**:
#   - Hotel: €80/noite → €160
#
# - **Praga (2 noites)**:
#   - Hotel: €70/noite → €140
#
# - **Viena (2 noites)**:
#   - Hotel: €100/noite → €200
#
# - **Roma (3 noites)**:
#   - Hotel: €120/noite → €360
#
# **Subtotal Hospedagem**: €360 + €200 + €160 + €140 + €200 + €360 = **€1,520**
#
# ---
#
# **3. Alimentação (14 dias)**:
# - **Café da manhã**:
#   - €10/dia → €140
#
# - **Almoço**:
#   - €15/dia → €210
#
# - **Jantar**:
#   - €25/dia → €350
#
# **Subtotal Alimentação**: €140 + €210 + €350 = **€700**
#
# ---
#
# **4. Atividades (14 dias)**:
# - **Paris**:
#   - Torre Eiffel: €30
#   - Museu do Louvre: €17
#   - Moulin Rouge (ingresso + consumação): €100
#   - Sacré-Cœur e Montmartre: gratuito
#
#   **Subtotal Paris**: €30 + €17 + €100 = €147
#
# - **Amsterdã**:
#   - Museu Van Gogh: €20
#   - Passeio de barco: €20
#   - Casa de Anne Frank: €12
#
#   **Subtotal Amsterdã**: €20 + €20 + €12 = €52
#
# - **Berlim**:
#   - Portão de Brandemburgo: gratuito
#   - Memorial do Holocausto: gratuito
#   - Museu da História da Alemanha: €8
#
#   **Subtotal Berlim**: €8
#
# - **Praga**:
#   - Castelo de Praga: €12
#   - Praça da Cidade Velha: gratuito
#
#   **Subtotal Praga**: €12
#
# - **Viena**:
#   - Palácio de Schönbrunn: €20
#   - Museu de História da Arte: €15
#
#   **Subtotal Viena**: €20 + €15 = €35
#
# - **Roma**:
#   - Coliseu e Fórum Romano: €18
#   - Vaticano (Museus Vaticanos + Basílica): €30
#
#   **Subtotal Roma**: €18 + €30 = €48
#
# **Subtotal Atividades**: €147 + €52 + €8 + €12 + €35 + €48 = **€302**
#
# ---
#
# **Total Geral da Viagem**:
# Transporte: €365
# Hospedagem: €1,520
# Alimentação: €700
# Atividades: €302
#
# **Custo Total Estimado da Viagem**:
# **€365 + €1,520 + €700 + €302 = €2,887**
#
# Esse orçamento detalha os custos aproximados da viagem, proporcionando uma estimativa realista para cada parte da aventura pela Europa, garantindo que a experiência seja inesquecível e dentro do planejamento financeiro.
